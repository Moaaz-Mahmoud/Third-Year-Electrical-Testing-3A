# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # 1. Data Wrangling

# %% [markdown]
# ## 1.1. Data Loading

# %%
df = pd.read_csv('Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv')
df.head()
# Out:
#    Order  Property Id                                 Property Name  \
# 0      1        13286                                       201/205
# 1      2        28400                    NYP Columbia (West Campus)
# 2      3      4778226                                 MSCHoNY North
# 3      4      4778267  Herbert Irving Pavilion & Millstein Hospital
# 4      5      4778288                               Neuro Institute
#
#   Parent Property Id        Parent Property Name BBL - 10 digits  \
# 0              13286                     201/205      1013160001
# 1              28400  NYP Columbia (West Campus)      1021380040
# 2              28400  NYP Columbia (West Campus)      1021380030
# 3              28400  NYP Columbia (West Campus)      1021390001
# 4              28400  NYP Columbia (West Campus)      1021390085
#
#   NYC Borough, Block and Lot (BBL) self-reported  \
# 0                                     1013160001
# 1                                   1-02138-0040
# 2                                   1-02138-0030
# 3                                   1-02139-0001
# 4                                   1-02139-0085
#
#             NYC Building Identification Number (BIN)  \
# 0                                            1037549
# 1  1084198; 1084387;1084385; 1084386; 1084388; 10...
# 2                                            1063380
# 3                                   1087281; 1076746
# 4                                            1063403
#
#   Address 1 (self-reported)                Address 2  ...  \
# 0  201/205  East  42nd  st.            Not Available  ...
# 1          622 168th Street            Not Available  ...
# 2             3975 Broadway            Not Available  ...
# 3   161 Fort Washington Ave  177 Fort Washington Ave  ...
# 4     710 West 168th Street            Not Available  ...
#
#   Source EUI (kBtu/ft²)            Release Date Water Required?  \
# 0                 619.4  05/01/2017 05:32:03 PM              No
# 1                 404.3  04/27/2017 11:23:27 AM              No
# 2         Not Available  04/27/2017 11:23:27 AM              No
# 3         Not Available  04/27/2017 11:23:27 AM              No
# 4         Not Available  04/27/2017 11:23:27 AM              No
#
#   DOF Benchmarking Submission Status   Latitude  Longitude Community Board  \
# 0                      In Compliance  40.750791 -73.973963             6.0
# 1                      In Compliance  40.841402 -73.942568            12.0
# 2                      In Compliance  40.840427 -73.940249            12.0
# 3                      In Compliance  40.840746 -73.942854            12.0
# 4                      In Compliance  40.841559 -73.942528            12.0
#
#   Council District Census Tract  \
# 0              4.0         88.0
# 1             10.0        251.0
# 2             10.0        251.0
# 3             10.0        255.0
# 4             10.0        255.0
#
#                                                  NTA
# 0  Turtle Bay-East Midtown                       ...
# 1  Washington Heights South                      ...
# 2  Washington Heights South                      ...
# 3  Washington Heights South                      ...
# 4  Washington Heights South                      ...
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11435 entries, 0 to 11434
# Data columns (total 60 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Order                                                       11435 non-null  int64
#  1   Property Id                                                 11435 non-null  int64
#  2   Property Name                                               11435 non-null  object
#  3   Parent Property Id                                          11435 non-null  object
#  4   Parent Property Name                                        11434 non-null  object
#  5   BBL - 10 digits                                             11423 non-null  object
#  6   NYC Borough, Block and Lot (BBL) self-reported              11434 non-null  object
#  7   NYC Building Identification Number (BIN)                    11434 non-null  object
#  8   Address 1 (self-reported)                                   11434 non-null  object
#  9   Address 2                                                   11434 non-null  object
#  10  Postal Code                                                 11434 non-null  object
#  11  Street Number                                               11314 non-null  object
#  12  Street Name                                                 11316 non-null  object
#  13  Borough                                                     11320 non-null  object
#  14  DOF Gross Floor Area                                        11320 non-null  float64
#  15  Primary Property Type - Self Selected                       11434 non-null  object
#  16  List of All Property Use Types at Property                  11434 non-null  object
#  17  Largest Property Use Type                                   11434 non-null  object
#  18  Largest Property Use Type - Gross Floor Area (ft²)          11434 non-null  object
#  19  2nd Largest Property Use Type                               11434 non-null  object
#  20  2nd Largest Property Use - Gross Floor Area (ft²)           11434 non-null  object
#  21  3rd Largest Property Use Type                               11434 non-null  object
#  22  3rd Largest Property Use Type - Gross Floor Area (ft²)      11434 non-null  object
#  23  Year Built                                                  11434 non-null  float64
#  24  Number of Buildings - Self-reported                         11434 non-null  float64
#  25  Occupancy                                                   11434 non-null  float64
#  26  Metered Areas (Energy)                                      11434 non-null  object
#  27  Metered Areas  (Water)                                      11434 non-null  object
#  28  ENERGY STAR Score                                           11434 non-null  object
#  29  Site EUI (kBtu/ft²)                                         11434 non-null  object
#  30  Weather Normalized Site EUI (kBtu/ft²)                      11434 non-null  object
#  31  Weather Normalized Site Electricity Intensity (kWh/ft²)     11434 non-null  object
#  32  Weather Normalized Site Natural Gas Intensity (therms/ft²)  11434 non-null  object
#  33  Weather Normalized Source EUI (kBtu/ft²)                    11434 non-null  object
#  34  Fuel Oil #1 Use (kBtu)                                      11434 non-null  object
#  35  Fuel Oil #2 Use (kBtu)                                      11434 non-null  object
#  36  Fuel Oil #4 Use (kBtu)                                      11434 non-null  object
#  37  Fuel Oil #5 & 6 Use (kBtu)                                  11434 non-null  object
#  38  Diesel #2 Use (kBtu)                                        11434 non-null  object
#  39  District Steam Use (kBtu)                                   11434 non-null  object
#  40  Natural Gas Use (kBtu)                                      11434 non-null  object
#  41  Weather Normalized Site Natural Gas Use (therms)            11434 non-null  object
#  42  Electricity Use - Grid Purchase (kBtu)                      11434 non-null  object
#  43  Weather Normalized Site Electricity (kWh)                   11434 non-null  object
#  44  Total GHG Emissions (Metric Tons CO2e)                      11434 non-null  object
#  45  Direct GHG Emissions (Metric Tons CO2e)                     11434 non-null  object
#  46  Indirect GHG Emissions (Metric Tons CO2e)                   11434 non-null  object
#  47  Property GFA - Self-Reported (ft²)                          11434 non-null  float64
#  48  Water Use (All Water Sources) (kgal)                        11434 non-null  object
#  49  Water Intensity (All Water Sources) (gal/ft²)               11434 non-null  object
#  50  Source EUI (kBtu/ft²)                                       11434 non-null  object
#  51  Release Date                                                11434 non-null  object
#  52  Water Required?                                             11328 non-null  object
#  53  DOF Benchmarking Submission Status                          11434 non-null  object
#  54  Latitude                                                    9306 non-null   float64
#  55  Longitude                                                   9306 non-null   float64
#  56  Community Board                                             9306 non-null   float64
#  57  Council District                                            9306 non-null   float64
#  58  Census Tract                                                9306 non-null   float64
#  59  NTA                                                         9306 non-null   object
# dtypes: float64(10), int64(2), object(48)
# memory usage: 5.2+ MB

# %% [markdown]
# ## 1.2. Data Cleaning

# %% [markdown]
# > Note
#
# > 34→37(sum)

# %%
df = df[df.columns[ [1, 24, 28, 34, 35, 36, 37, 38, 40, 41, 42, 43, 44, 47, 48, 49, 50, 52, 59] ]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11435 entries, 0 to 11434
# Data columns (total 19 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Property Id                                       11435 non-null  int64
#  1   Number of Buildings - Self-reported               11434 non-null  float64
#  2   ENERGY STAR Score                                 11434 non-null  object
#  3   Fuel Oil #1 Use (kBtu)                            11434 non-null  object
#  4   Fuel Oil #2 Use (kBtu)                            11434 non-null  object
#  5   Fuel Oil #4 Use (kBtu)                            11434 non-null  object
#  6   Fuel Oil #5 & 6 Use (kBtu)                        11434 non-null  object
#  7   Diesel #2 Use (kBtu)                              11434 non-null  object
#  8   Natural Gas Use (kBtu)                            11434 non-null  object
#  9   Weather Normalized Site Natural Gas Use (therms)  11434 non-null  object
#  10  Electricity Use - Grid Purchase (kBtu)            11434 non-null  object
#  11  Weather Normalized Site Electricity (kWh)         11434 non-null  object
#  12  Total GHG Emissions (Metric Tons CO2e)            11434 non-null  object
#  13  Property GFA - Self-Reported (ft²)                11434 non-null  float64
#  14  Water Use (All Water Sources) (kgal)              11434 non-null  object
#  15  Water Intensity (All Water Sources) (gal/ft²)     11434 non-null  object
#  16  Source EUI (kBtu/ft²)                             11434 non-null  object
#  17  Water Required?                                   11328 non-null  object
#  18  NTA                                               9306 non-null   object
# dtypes: float64(2), int64(1), object(16)
# memory usage: 1.7+ MB

# %%
df.drop_duplicates(inplace=True)
df[df.columns[0]].size
# Out:
# 11435

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9232 entries, 0 to 10792
# Data columns (total 19 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Property Id                                       9232 non-null   int64
#  1   Number of Buildings - Self-reported               9232 non-null   float64
#  2   ENERGY STAR Score                                 9232 non-null   object
#  3   Fuel Oil #1 Use (kBtu)                            9232 non-null   object
#  4   Fuel Oil #2 Use (kBtu)                            9232 non-null   object
#  5   Fuel Oil #4 Use (kBtu)                            9232 non-null   object
#  6   Fuel Oil #5 & 6 Use (kBtu)                        9232 non-null   object
#  7   Diesel #2 Use (kBtu)                              9232 non-null   object
#  8   Natural Gas Use (kBtu)                            9232 non-null   object
#  9   Weather Normalized Site Natural Gas Use (therms)  9232 non-null   object
#  10  Electricity Use - Grid Purchase (kBtu)            9232 non-null   object
#  11  Weather Normalized Site Electricity (kWh)         9232 non-null   object
#  12  Total GHG Emissions (Metric Tons CO2e)            9232 non-null   object
#  13  Property GFA - Self-Reported (ft²)                9232 non-null   float64
#  14  Water Use (All Water Sources) (kgal)              9232 non-null   object
#  15  Water Intensity (All Water Sources) (gal/ft²)     9232 non-null   object
#  16  Source EUI (kBtu/ft²)                             9232 non-null   object
#  17  Water Required?                                   9232 non-null   object
#  18  NTA                                               9232 non-null   object
# dtypes: float64(2), int64(1), object(16)
# memory usage: 1.4+ MB

# %%
df.drop(
    [df.columns[2], df.columns[3], df.columns[4], df.columns[5], df.columns[6], df.columns[15]],
    axis='columns',
    inplace=True
)

df_3_6_sum = pd.Series([0]*df[df.columns[4]].size)
df.info()
df.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9232 entries, 0 to 10792
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Property Id                                       9232 non-null   int64
#  1   Number of Buildings - Self-reported               9232 non-null   float64
#  2   Diesel #2 Use (kBtu)                              9232 non-null   object
#  3   Natural Gas Use (kBtu)                            9232 non-null   object
#  4   Weather Normalized Site Natural Gas Use (therms)  9232 non-null   object
#  5   Electricity Use - Grid Purchase (kBtu)            9232 non-null   object
#  6   Weather Normalized Site Electricity (kWh)         9232 non-null   object
#  7   Total GHG Emissions (Metric Tons CO2e)            9232 non-null   object
#  8   Property GFA - Self-Reported (ft²)                9232 non-null   float64
#  9   Water Use (All Water Sources) (kgal)              9232 non-null   object
#  10  Source EUI (kBtu/ft²)                             9232 non-null   object
#  11  Water Required?                                   9232 non-null   object
#  12  NTA                                               9232 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1009.8+ KB
#     Property Id  Number of Buildings - Self-reported Diesel #2 Use (kBtu)  \
# 0         13286                                  2.0        Not Available
# 1         28400                                 12.0        Not Available
# 2       4778226                                  1.0        Not Available
# 3       4778267                                  1.0        Not Available
# 4       4778288                                  1.0        Not Available
# 5         28402                                 12.0        Not Available
# 6       4778352                                  1.0        Not Available
# 7       2610789                                  4.0        Not Available
# 8       2611745                                  1.0        Not Available
# 9       3616379                                  1.0        Not Available
# 10      5870374                                  1.0        Not Available
# 15      5245390                                  1.0        Not Available
# 20      4988569                                  1.0        Not Available
# 23      4988688                                  1.0        Not Available
# 25      4954491                                  1.0        Not Available
#
#    Natural Gas Use (kBtu) Weather Normalized Site Natural Gas Use (therms)  \
# 0           Not Available                                    Not Available
# 1               933073441                                        9330734.4
# 2           Not Available                                    Not Available
# 3           Not Available                                    Not Available
# 4           Not Available                                    Not Available
# 5          1.4322508769E9                                     1.43225088E7
# 6           Not Available                                    Not Available
# 7            394285242148                                   3.9428524215E9
# 8           Not Available                                    Not Available
# 9           Not Available                                    Not Available
# 10          Not Available                                    Not Available
# 15          Not Available                                    Not Available
# 20               326760.6                                           3301.9
# 23                59412.9                                              601
# 25                      0                                                0
#
#    Electricity Use - Grid Purchase (kBtu)  \
# 0                              38139374.2
# 1                               332365924
# 2                           Not Available
# 3                           Not Available
# 4                           Not Available
# 5                              86335350.5
# 6                           Not Available
# 7                           Not Available
# 8                                227658.1
# 9                           Not Available
# 10                          Not Available
# 15                          Not Available
# 20                              1081789.4
# 23                               923332.2
# 25                                      0
#
#    Weather Normalized Site Electricity (kWh)  \
# 0                               1.10827705E7
# 1                               9.62613121E7
# 2                              Not Available
# 3                              Not Available
# 4                              Not Available
# 5                               2.45508594E7
# 6                              Not Available
# 7                              Not Available
# 8                                    63979.9
# 9                              Not Available
# 10                             Not Available
# 15                             Not Available
# 20                                  308074.6
# 23                                  262377.2
# 25                                         0
#
#    Total GHG Emissions (Metric Tons CO2e)  Property GFA - Self-Reported (ft²)  \
# 0                                  6962.2                            762051.0
# 1                                 55870.4                           3889181.0
# 2                                       0                            231342.0
# 3                                       0                           1305748.0
# 4                                       0                            179694.0
# 5                                 54429.8                           2971874.0
# 6                                       0                            245000.0
# 7                                20943400                           2738875.0
# 8                                    21.1                               200.0
# 9                                       0                            912892.0
# 10                                      0                            912892.0
# 15                                      0                            567517.0
# 20                                    689                            116744.0
# 23                                   88.8                             54913.0
# 25                                      0                            256528.0
#
#    Water Use (All Water Sources) (kgal) Source EUI (kBtu/ft²) Water Required?  \
# 0                         Not Available                 619.4              No
# 1                         Not Available                 404.3              No
# 2                         Not Available         Not Available              No
# 3                         Not Available         Not Available              No
# 4                         Not Available         Not Available              No
# 5                         Not Available                 414.2              No
# 6                         Not Available         Not Available             Yes
# 7                              107151.5              151172.9             Yes
# 8                               19261.1                3574.2             Yes
# 9                         Not Available         Not Available             Yes
# 10                        Not Available         Not Available             Yes
# 15                        Not Available         Not Available             Yes
# 20                        Not Available                  97.7             Yes
# 23                                231.9                  53.9             Yes
# 25                        Not Available                     0             Yes
#
#                                                   NTA
# 0   Turtle Bay-East Midtown                       ...
# 1   Washington Heights South                      ...
# 2   Washington Heights South                      ...
# 3   Washington Heights South                      ...
# 4   Washington Heights South                      ...
# 5   Lenox Hill-Roosevelt Island                   ...
# 6   Lenox Hill-Roosevelt Island                   ...
# 7   Glen Oaks-Floral Park-New Hyde Park           ...
# 8   Glen Oaks-Floral Park-New Hyde Park           ...
# 9   Glen Oaks-Floral Park-New Hyde Park           ...
# 10  Glen Oaks-Floral Park-New Hyde Park           ...
# 15  Old Town-Dongan Hills-South Beach             ...
# 20  Washington Heights North                      ...
# 23  Upper East Side-Carnegie Hill                 ...
# 25  Morningside Heights                           ...

# %% [markdown]
# ## Project Abandoned!
